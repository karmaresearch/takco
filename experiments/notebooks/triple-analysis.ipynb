# %% [markdown]
# # T2K Triples

# %%
import os
rdirs = [rdir for rdir in os.listdir('results') if 'triples' in os.listdir(os.path.join('results', rdir))]
sorted(rdirs)
# Out:
# ['16oct-f1-bp1',
#  '19oct-v2-f1-bp1',
#  '1nov-v1-check',
#  '23oct-v1-goldcandidates-f1-bp1',
#  '29oct-v1-goldcandidatesfixed-f1-bp1',
#  '30oct-v1-goldcandidatesadded-f1-bp1',
#  '31oct-v1-goldcandidatesadded-dbpediapart-f1-bp1',
#  '31oct-v1-goldcandidatesadded-wikidata-labels',
#  '31oct-v2-goldcandidatesadded-dbpediapart-labels',
#  '31oct-v2-goldcandidatesadded-labels',
#  '31oct-v2-goldcandidatesadded-wikidata-labels']

# %%
import os
from functools import reduce
import pandas as pd

# results_dir = 'results/16oct-f1-bp1/'
# results_dir = 'results/23oct-v1-goldcandidates-f1-bp1/'
# results_dir = 'results/29oct-v1-goldcandidatesfixed-f1-bp1/'
# results_dir = 'results/30oct-v1-goldcandidatesadded-f1-bp1/'
# results_dir = 'results/31oct-v1-goldcandidatesadded-dbpediapart-f1-bp1/'
# results_dir = 'results/31oct-v1-goldcandidatesadded-wikidata-labels/'
results_dir = 'results/1nov-v1-check/'

# !ls $results_dir

triple_dir = os.path.join(results_dir, 'triples')
triple_tables = []
methods = [m for m in os.listdir(triple_dir) if not m.endswith('.csv')]
for method in methods:
    t = pd.read_csv(os.path.join(results_dir, 'triples', method, 'extracted_triples-GOLD.csv'))
    t.rename(columns={'Subject Confidence':method}, inplace=True)
    triple_tables.append(t)
join_triples = reduce(lambda left, right: left.merge(right, how='outer'), triple_tables)
join_triples.fillna(0, inplace=True)
join_triples.to_csv(os.path.join(triple_dir, 'extracted_triples.csv'))

# %%
m = 't2k-final'

P = (join_triples[m]>0)
G = (join_triples['gold']>0)
K = (join_triples['Object Value matches KB'] == True)

Rpos = sum(P & G & K) / sum(P & G)
Rneg = sum((~P) & G & K) / sum(G & (~P))
print('P %.2f > %.2f' % (Rpos, Rneg))

Qnov = sum(P & G & (~K)) / sum(G & (~K))
Qred = sum(P & G & K) / sum(G & K)

print('Q %.2f < %.2f' % (Qnov, Qred))
# Out:
# P 0.40 > 0.24
# Q 0.70 < 0.84

# %%
# %matplotlib inline
import collections
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(10,5))

jt = join_triples.copy()
jt = jt.drop(columns=['URL', 'Table', 'Column Index']).drop_duplicates()

scores = []
for redundant, ax in [(True, ax1), (False, ax2)]:
    for method in methods:
        if method != 'gold':
            j = jt[(jt['Object Value matches KB'] == redundant)]
            y_test = j['gold']
            y_score = j[method]
            p_curve, r_curve, _ = precision_recall_curve(list(y_test), list(y_score))
            ax.step(r_curve[1:-1], p_curve[1:-1], where='post', label='%s' % method)
            
#             f_curve = 2 / ((1/p_curve) + (1/r_curve))
#             t = f_curve[1:-1].argmax()+1
#             ax.plot([r_curve[t]], [p_curve[t]], marker='x', color="black")
#             ax.text(r_curve[t], p_curve[t], '$f_1$:%.2f' % f_curve[t])
            
            n_correct = sum((y_score > 0) & (y_test > 0))
            p = n_correct / sum(y_score > 0) if sum(y_score > 0) else 0
            r = n_correct / sum(y_test > 0) if sum(y_test > 0) else 0
            f = 2 / ((1/p) + (1/r)) if p and r else 0
            ap = average_precision_score(list(y_test), list(y_score))

            scores.append(collections.OrderedDict(
                redundant=redundant, method=method,
                precision=p,recall=r,f1=f,ap=ap,
                p_curve=p_curve, r_curve=r_curve,
            ))
            
    ax.set_title(['Novel', 'Redundant'][int(redundant)])
    ax.set_xlabel('Recall')
    ax.set_ylabel('Precision')
    ax.set_xlim([0,1])
ax.legend()

import json
json.dump(scores, os.path.join(results_dir,'triple_scores.json'))

df = pd.DataFrame(scores)
df = df[['redundant','method','precision','recall','f1','ap']]
df.columns = ['Redundant', 'System', 'Precision','Recall','$F_1$','AP']
df = df.pivot(index='System', columns='Redundant')
df.columns = df.columns.swaplevel(0, 1)
df.sortlevel(0, axis=1, inplace=True, sort_remaining=False)
df = df.reindex(index=df.index[::-1])
df
# Out:
# /export/scratch1/home/kruit/venv/lib/python3.6/site-packages/ipykernel_launcher.py:46: FutureWarning: sortlevel is deprecated, use sort_index(level= ...)
# redundant              False                                   True   \
#                    precision    recall        f1        ap precision
# method
# t2k-final           0.671656  0.654315  0.662872  0.597860  0.881153
# sti                 0.656946  0.514968  0.577357  0.544386  0.892552
# labelscore_ft0_bp0  0.454186  0.772560  0.572059  0.447516  0.836124
# combined_ft0_bp0    0.728889  0.789629  0.758044  0.801749  0.919502
# coherence_ft0_bp0   0.717461  0.779465  0.747179  0.794662  0.914323
#
# redundant
#                       recall        f1        ap
# method
# t2k-final           0.819604  0.849265  0.898826
# sti                 0.701345  0.785479  0.856844
# labelscore_ft0_bp0  0.844586  0.840334  0.846354
# combined_ft0_bp0    0.856900  0.887098  0.930757
# coherence_ft0_bp0   0.848903  0.880399  0.920958

# %%
jt = join_triples.copy()
jt['gold and t2k'] = (jt['t2k-final'] > 0) & (join_triples['gold']>0)

print('%20s: %d triples' % ('total', len(join_triples)))

for redundant,r in [(True, 'redundant'), (False, 'novel')]:
    for m in ['gold', 't2k-final', 'gold and t2k']:
        novel_triples = jt[(jt['Object Value matches KB'] == redundant)]
        recall = (novel_triples[m]>0).sum() / (novel_triples['gold']>0).sum()
        print('%20s: %d triples, %d %s' % (r, len(novel_triples), (novel_triples[m]>0).sum(), m))
# Out:
#                total: 61039 triples
#            redundant: 17413 triples, 15751 gold
#            redundant: 17413 triples, 13740 t2k-final
#            redundant: 17413 triples, 13294 gold and t2k
#                novel: 43626 triples, 31199 gold
#                novel: 43626 triples, 26705 t2k-final
#                novel: 43626 triples, 25395 gold and t2k

# %%
join_triples[(join_triples['labelscore_ft0_bp0'] == 0) & (join_triples['gold'] == 1)]
# Out:
#        URL                               Table  Column Index  \
# 25     0.0  61121469_0_6337620713408906340.csv             1
# 37     0.0  29414811_2_4773219892816395776.csv             2
# 58     0.0  29414811_2_4773219892816395776.csv             4
# 79     0.0  29414811_2_4773219892816395776.csv             0
# 100    0.0  29414811_2_4773219892816395776.csv             3
# 142    0.0  38428277_0_1311643810102462607.csv             3
# 156    0.0  38428277_0_1311643810102462607.csv             3
# 176    0.0  38428277_0_1311643810102462607.csv             3
# 183    0.0  38428277_0_1311643810102462607.csv             3
#
#                           Subject Value  t2k-final  \
# 25                           madagascar    0.91458
# 37                        metroid prime    0.86409
# 58                        metroid prime    0.86409
# 79                        metroid prime    0.86409
# 100                       metroid prime    0.86409
# 142                          the matrix    0.94778
# 156                           nosferatu    0.95268
# 176                        philadelphia    0.67564
# 183                           manhattan    0.68078
# 196                       moulin rouge!    0.96707
# 200            night of the living dead    0.96995
# 203                         peeping tom    0.77107
# 252                          the matrix    0.94778
# 266                           nosferatu    0.95268
# 286                        philadelphia    0.67564
# 293                           manhattan    0.68078
# 306                       moulin rouge!    0.96707
# 310            night of the living dead    0.96995
# 313                         peeping tom    0.77107
# 2860                      the lion king    0.97998
# 2922                              shrek    1.00000
# 2923                          manhattan    0.68438
# 2953                      the lion king    0.97998
# 3015                              shrek    1.00000
# 3016                          manhattan    0.68438
# 3246                super mario bros. 2    0.93837
# 3281                       spider-man 3    0.71348
# 3449                       perfect dark    0.98458
# 3529                    bank of america    0.97192
# 3546                    bank of america    0.97192
# ...                                 ...        ...
# 73258                            lufeng    0.00000
# 73259                           kowloon    0.00000
# 73260                         lianjiang    0.00000
# 73261                        la matanza    0.00000
# 73262  birmingham international airport    0.00000
# 73263  birmingham international airport    0.00000
# 73264                       the visitor    0.00000
# 73265                      ghost writer    0.00000
# 73266                       the visitor    0.00000
# 73267                      ghost writer    0.00000
# 73268                           buffalo    0.00000
# 73269                           colombo    0.00000
# 73270                          chaoyang    0.00000
# 73271                          columbus    0.00000
# 73272                           cordoba    0.00000
# 73273                         allahabad    0.00000
# 73274                           colombo    0.00000
# 73275                           buffalo    0.00000
# 73276                           colombo    0.00000
# 73277                          chaoyang    0.00000
# 73278                          columbus    0.00000
# 73279                           cordoba    0.00000
# 73280                         allahabad    0.00000
# 73281                           colombo    0.00000
# 73282                           buffalo    0.00000
# 73283                           colombo    0.00000
# 73284                          columbus    0.00000
# 73285                           cordoba    0.00000
# 73286                         allahabad    0.00000
# 73287                           colombo    0.00000
#
#                                            Predicate URI  \
# 25                   http://dbpedia.org/ontology/capital
# 37                     http://dbpedia.org/ontology/genre
# 58                 http://dbpedia.org/ontology/developer
# 79                      http://dbpedia.org/ontology/year
# 100        http://dbpedia.org/ontology/computingPlatform
# 142                 http://dbpedia.org/ontology/director
# 156                 http://dbpedia.org/ontology/director
# 176                 http://dbpedia.org/ontology/director
# 183                 http://dbpedia.org/ontology/director
# 196                 http://dbpedia.org/ontology/director
# 200                 http://dbpedia.org/ontology/director
# 203                 http://dbpedia.org/ontology/director
# 252              http://dbpedia.org/ontology/releaseDate
# 266              http://dbpedia.org/ontology/releaseDate
# 286              http://dbpedia.org/ontology/releaseDate
# 293              http://dbpedia.org/ontology/releaseDate
# 306              http://dbpedia.org/ontology/releaseDate
# 310              http://dbpedia.org/ontology/releaseDate
# 313              http://dbpedia.org/ontology/releaseDate
# 2860             http://dbpedia.org/ontology/releaseDate
# 2922             http://dbpedia.org/ontology/releaseDate
# 2923             http://dbpedia.org/ontology/releaseDate
# 2953                http://dbpedia.org/ontology/director
# 3015                http://dbpedia.org/ontology/director
# 3016                http://dbpedia.org/ontology/director
# 3246       http://dbpedia.org/ontology/computingPlatform
# 3281       http://dbpedia.org/ontology/computingPlatform
# 3449       http://dbpedia.org/ontology/computingPlatform
# 3529                 http://dbpedia.org/ontology/revenue
# 3546             http://dbpedia.org/ontology/headquarter
# ...                                                  ...
# 73258                http://dbpedia.org/ontology/country
# 73259                http://dbpedia.org/ontology/country
# 73260                http://dbpedia.org/ontology/country
# 73261                http://dbpedia.org/ontology/country
# 73262                   http://dbpedia.org/ontology/city
# 73263  http://dbpedia.org/ontology/iataLocationIdenti...
# 73264               http://dbpedia.org/ontology/director
# 73265               http://dbpedia.org/ontology/director
# 73266            http://dbpedia.org/ontology/releaseDate
# 73267            http://dbpedia.org/ontology/releaseDate
# 73268        http://dbpedia.org/ontology/populationTotal
# 73269        http://dbpedia.org/ontology/populationTotal
# 73270        http://dbpedia.org/ontology/populationTotal
# 73271        http://dbpedia.org/ontology/populationTotal
# 73272        http://dbpedia.org/ontology/populationTotal
# 73273        http://dbpedia.org/ontology/populationTotal
# 73274        http://dbpedia.org/ontology/populationTotal
# 73275                http://dbpedia.org/ontology/country
# 73276                http://dbpedia.org/ontology/country
# 73277                http://dbpedia.org/ontology/country
# 73278                http://dbpedia.org/ontology/country
# 73279                http://dbpedia.org/ontology/country
# 73280                http://dbpedia.org/ontology/country
# 73281                http://dbpedia.org/ontology/country
# 73282        http://dbpedia.org/ontology/populationMetro
# 73283        http://dbpedia.org/ontology/populationMetro
# 73284        http://dbpedia.org/ontology/populationMetro
# 73285        http://dbpedia.org/ontology/populationMetro
# 73286        http://dbpedia.org/ontology/populationMetro
# 73287        http://dbpedia.org/ontology/populationMetro
#
#                    Predicate Value  Predicate Confidence Data Type  \
# 25                    capital city                   1.0    string
# 37                           genre                   1.0    string
# 58                    developer(s)                   1.0    string
# 79                            year                   1.0      date
# 100                    platform(s)                   1.0    string
# 142                    director(s)                   1.0    string
# 156                    director(s)                   1.0    string
# 176                    director(s)                   1.0    string
# 183                    director(s)                   1.0    string
# 196                    director(s)                   1.0    string
# 200                    director(s)                   1.0    string
# 203                    director(s)                   1.0    string
# 252                           year                   1.0      date
# 266                           year                   1.0      date
# 286                           year                   1.0      date
# 293                           year                   1.0      date
# 306                           year                   1.0      date
# 310                           year                   1.0      date
# 313                           year                   1.0      date
# 2860                          year                   1.0      date
# 2922                          year                   1.0      date
# 2923                          year                   1.0      date
# 2953                   director(s)                   1.0    string
# 3015                   director(s)                   1.0    string
# 3016                   director(s)                   1.0    string
# 3246                        system                   1.0    string
# 3281                        system                   1.0    string
# 3449                        system                   1.0    string
# 3529             revenue(billion )                   1.0   numeric
# 3546                  headquarters                   1.0    string
# ...                            ...                   ...       ...
# 73258                      country                   1.0    string
# 73259                      country                   1.0    string
# 73260                      country                   1.0    string
# 73261                      country                   1.0    string
# 73262                         city                   1.0    string
# 73263                         code                   1.0    string
# 73264                     director                   1.0    string
# 73265                     director                   1.0    string
# 73266                         year                   1.0      date
# 73267                         year                   1.0      date
# 73268   city            population                   1.0   numeric
# 73269   city            population                   1.0   numeric
# 73270   city            population                   1.0   numeric
# 73271   city            population                   1.0   numeric
# 73272   city            population                   1.0   numeric
# 73273   city            population                   1.0   numeric
# 73274   city            population                   1.0   numeric
# 73275                      country                   1.0    string
# 73276                      country                   1.0    string
# 73277                      country                   1.0    string
# 73278                      country                   1.0    string
# 73279                      country                   1.0    string
# 73280                      country                   1.0    string
# 73281                      country                   1.0    string
# 73282  metro            population                   1.0   numeric
# 73283  metro            population                   1.0   numeric
# 73284  metro            population                   1.0   numeric
# 73285  metro            population                   1.0   numeric
# 73286  metro            population                   1.0   numeric
# 73287  metro            population                   1.0   numeric
#
#                           Object Value  \
# 25                        antananarivo
# 37                    action-adventure
# 58                            nintendo
# 79                    2002-01-01T00:00
# 100                  nintendo gamecube
# 142           andy and larry wachowski
# 156                        f.w. murnau
# 176                     jonathan demme
# 183                        woody allen
# 196                       baz luhrmann
# 200                   george a. romero
# 203                     michael powell
# 252                   1999-01-01T00:00
# 266                   1922-01-01T00:00
# 286                   1993-01-01T00:00
# 293                   1979-01-01T00:00
# 306                   2001-01-01T00:00
# 310                   1968-01-01T00:00
# 313                   1960-01-01T00:00
# 2860                  1994-01-01T00:00
# 2922                  2001-01-01T00:00
# 2923                  1979-01-01T00:00
# 2953      roger allers and rob minkoff
# 3015   andrew adamson and vicky jenson
# 3016                       woody allen
# 3246                               nes
# 3281                sony playstation 2
# 3449                       nintendo 64
# 3529                            116.57
# 3546                               usa
# ...                                ...
# 73258                            china
# 73259                            china
# 73260                            china
# 73261                        argentina
# 73262                       birmingham
# 73263                              bhm
# 73264                     tom mccarthy
# 73265                   roman polanski
# 73266                 2007-01-01T00:00
# 73267                 2010-01-01T00:00
# 73268                         296000.0
# 73269                         247000.0
# 73270                        2471000.0
# 73271                         714000.0
# 73272                        1310000.0
# 73273                        1215000.0
# 73274                         650000.0
# 73275                              usa
# 73276                           brazil
# 73277                            china
# 73278                              usa
# 73279                        argentina
# 73280                            india
# 73281                        sri lanka
# 73282                        1572000.0
# 73283                        2160000.0
# 73284                        1540000.0
# 73285                        1528000.0
# 73286                        1250000.0
# 73287                        2400000.0
#
#                                       Object Value in KB  \
# 25                                          Antananarivo
# 37                            First-person (video games)
# 58                              {Nintendo|Retro Studios}
# 79                                                     0
# 100                                       {Wii|GameCube}
# 142                                                    0
# 156                                         F. W. Murnau
# 176                                       Jonathan Demme
# 183                                          Woody Allen
# 196                                         Baz Luhrmann
# 200                                     George A. Romero
# 203                                       Michael Powell
# 252                                                    0
# 266                                                    0
# 286                                                    0
# 293                                                    0
# 306                                                    0
# 310                                                    0
# 313                                                    0
# 2860                                                   0
# 2922                                                   0
# 2923                                                   0
# 2953                                                   0
# 3015                                                   0
# 3016                                         Woody Allen
# 3246   {Game Boy Advance|Super Nintendo Entertainment...
# 3281   {Game Boy Advance|Microsoft Windows|PlayStatio...
# 3449                                         Nintendo 64
# 3529                                            8.894E10
# 3546                                                   0
# ...                                                  ...
# 73258                                                  0
# 73259                                                  0
# 73260                                                  0
# 73261                                                  0
# 73262                                         Birmingham
# 73263                                                BHX
# 73264                            Thomas McCarthy (actor)
# 73265                                     Roman Polanski
# 73266                                                  0
# 73267                                                  0
# 73268                                           259384.0
# 73269                                              247.0
# 73270                                          3044641.0
# 73271                                           787033.0
# 73272                                          1309536.0
# 73273                                                  0
# 73274                                              247.0
# 73275                                                  0
# 73276                                                  0
# 73277                                              China
# 73278                                                  0
# 73279                                                  0
# 73280                                                  0
# 73281                                                  0
# 73282                                          1134210.0
# 73283                                                  0
# 73284                                          2348495.0
# 73285                                          1528000.0
# 73286                                                  0
# 73287                                                  0
#
#        Object Value matches KB  Object Value Similarity  labelscore_ft0_bp0  \
# 25                        True                 1.000000                 0.0
# 37                       False                 0.000000                 0.0
# 58                       False                 0.000000                 0.0
# 79                       False                 0.000000                 0.0
# 100                      False                 0.000000                 0.0
# 142                      False                 0.000000                 0.0
# 156                       True                 1.000000                 0.0
# 176                       True                 1.000000                 0.0
# 183                       True                 1.000000                 0.0
# 196                       True                 1.000000                 0.0
# 200                       True                 1.000000                 0.0
# 203                       True                 1.000000                 0.0
# 252                      False                 0.000000                 0.0
# 266                      False                 0.000000                 0.0
# 286                      False                 0.000000                 0.0
# 293                      False                 0.000000                 0.0
# 306                      False                 0.000000                 0.0
# 310                      False                 0.000000                 0.0
# 313                      False                 0.000000                 0.0
# 2860                     False                 0.000000                 0.0
# 2922                     False                 0.000000                 0.0
# 2923                     False                 0.000000                 0.0
# 2953                     False                 0.000000                 0.0
# 3015                     False                 0.000000                 0.0
# 3016                      True                 1.000000                 0.0
# 3246                     False                 0.000000                 0.0
# 3281                     False                 0.000000                 0.0
# 3449                      True                 1.000000                 0.0
# 3529                     False                 0.000000                 0.0
# 3546                     False                 0.000000                 0.0
# ...                        ...                      ...                 ...
# 73258                    False                 0.000000                 0.0
# 73259                    False                 0.000000                 0.0
# 73260                    False                 0.000000                 0.0
# 73261                    False                 0.000000                 0.0
# 73262                     True                 1.000000                 0.0
# 73263                     True                 0.500000                 0.0
# 73264                    False                 0.000000                 0.0
# 73265                     True                 1.000000                 0.0
# 73266                    False                 0.000000                 0.0
# 73267                    False                 0.000000                 0.0
# 73268                    False                 0.000000                 0.0
# 73269                    False                 0.000000                 0.0
# 73270                    False                 0.000000                 0.0
# 73271                    False                 0.000000                 0.0
# 73272                     True                 0.992916                 0.0
# 73273                    False                 0.000000                 0.0
# 73274                    False                 0.000000                 0.0
# 73275                    False                 0.000000                 0.0
# 73276                    False                 0.000000                 0.0
# 73277                     True                 1.000000                 0.0
# 73278                    False                 0.000000                 0.0
# 73279                    False                 0.000000                 0.0
# 73280                    False                 0.000000                 0.0
# 73281                    False                 0.000000                 0.0
# 73282                    False                 0.000000                 0.0
# 73283                    False                 0.000000                 0.0
# 73284                    False                 0.000000                 0.0
# 73285                     True                 1.000000                 0.0
# 73286                    False                 0.000000                 0.0
# 73287                    False                 0.000000                 0.0
#
#        gold       sti  combined_ft0_bp0  coherence_ft0_bp0
# 25      1.0  2.390152          0.453828           0.215694
# 37      1.0  2.010153          0.000000           0.115581
# 58      1.0  2.010153          0.000000           0.115581
# 79      1.0  2.010153          0.000000           0.115581
# 100     1.0  2.010153          0.000000           0.115581
# 142     1.0  1.808122          1.175978           0.494569
# 156     1.0  2.200000          0.928786           0.247377
# 176     1.0  1.976326          1.206883           0.525473
# 183     1.0  1.966326          1.200140           0.518730
# 196     1.0  0.000000          0.000000           0.000000
# 200     1.0  1.599673          1.176779           0.495370
# 203     1.0  1.762585          1.083781           0.402372
# 252     1.0  1.808122          1.175978           0.494569
# 266     1.0  2.200000          0.928786           0.247377
# 286     1.0  1.976326          1.206883           0.525473
# 293     1.0  1.966326          1.200140           0.518730
# 306     1.0  0.000000          0.000000           0.000000
# 310     1.0  1.599673          1.176779           0.495370
# 313     1.0  1.762585          1.083781           0.402372
# 2860    1.0  1.578808          1.070484           0.394733
# 2922    1.0  2.005025          0.983905           0.308438
# 2923    1.0  2.032993          1.176646           0.501179
# 2953    1.0  1.578808          1.070484           0.394733
# 3015    1.0  2.005025          0.983905           0.308438
# 3016    1.0  2.032993          1.176646           0.501179
# 3246    1.0  1.519097          0.000000           0.000000
# 3281    1.0  1.293910          0.806019           0.177952
# 3449    1.0  2.180964          0.000000           0.000000
# 3529    1.0  1.638858          0.564409           0.184075
# 3546    1.0  1.638858          0.564409           0.184075
# ...     ...       ...               ...                ...
# 73258   1.0  2.142210          0.000000           0.000000
# 73259   1.0  0.000000          0.313931           0.078413
# 73260   1.0  1.975543          0.000000           0.000000
# 73261   1.0  0.000000          0.000000           0.000000
# 73262   1.0  0.000000          0.000000           0.000000
# 73263   1.0  0.000000          0.000000           0.000000
# 73264   1.0  0.000000          1.328620           0.591400
# 73265   1.0  0.000000          0.942255           0.450774
# 73266   1.0  0.000000          1.328620           0.591400
# 73267   1.0  0.000000          0.942255           0.450774
# 73268   1.0  1.919164          0.000000           0.085163
# 73269   1.0  0.000000          0.000000           0.000000
# 73270   1.0  1.971277          0.291578           0.045504
# 73271   1.0  2.066515          0.212395           0.096348
# 73272   1.0  0.290665          0.000000           0.013704
# 73273   1.0  2.000000          0.320706           0.096855
# 73274   1.0  0.000000          0.000000           0.000000
# 73275   1.0  1.919164          0.000000           0.085163
# 73276   1.0  0.000000          0.000000           0.000000
# 73277   1.0  1.971277          0.291578           0.045504
# 73278   1.0  2.066515          0.212395           0.096348
# 73279   1.0  0.290665          0.000000           0.013704
# 73280   1.0  2.000000          0.320706           0.096855
# 73281   1.0  0.000000          0.000000           0.000000
# 73282   1.0  1.919164          0.000000           0.085163
# 73283   1.0  0.000000          0.000000           0.000000
# 73284   1.0  2.066515          0.212395           0.096348
# 73285   1.0  0.290665          0.000000           0.013704
# 73286   1.0  2.000000          0.320706           0.096855
# 73287   1.0  0.000000          0.000000           0.000000
#
# [2644 rows x 19 columns]

# %% [markdown]
# # Properties
# not used now

# %%
import os, glob
import pandas as pd

# %%
gold_path = './data_t2k/v1/'
gold_prop_fname = os.path.join(gold_path,'gs_property.csv') # needed for gold subject column
gs_property = pd.read_csv(gold_prop_fname, header=None, names=['col', 'uri', 'gold'])
gs_property['table'], gs_property['columnIndex'] = zip(*(s.split('~Col') for s in gs_property['col']))
gs_property['columnIndex'] = gs_property['columnIndex'].map(int)

# %%
our_path = './results/16oct-f1-bp1/'
our_property = pd.concat([
    pd.read_csv(fname).append(pd.DataFrame({'table':[]}), sort=False).fillna(os.path.basename(fname))
    for fname in glob.glob(os.path.join(our_path, 'property', '*'))
])
