# %% [markdown]
# # Comparison to SNoW
#
# > Given a set of web tables and a target knowledge base, the SNoW method extends each web table with additional context columns, stitches matching web tables into larger tables, and applies functional dependency discovery to identify the relations that are represented in the web tables. Further, it normalises the stitched tables, guided by the schema of the knowledge base, to create an integrated schema.
#
# We assume that the tables are already context-enriched, and schema-unioned per Pay-Level Domain. Our task is now to match and stitch these supertables into universal tables, and decompose them into normalised relations.

# %% [markdown]
# ## Matching without FDs

# %%
# %%time
from snow_pipeline import *
log.getLogger().setLevel(log.DEBUG)

snow_root = Path('~/snow/').expanduser().absolute()
kb = KB(snow_root)
# Out:
# Loading KB classes: 100%|██████████| 20/20 [00:03<00:00,  5.35it/s]
# DEBUG:root:Made KB feature matrix of shape (20, 2336698)
# CPU times: user 35.4 s, sys: 1.34 s, total: 36.7 s
# Wall time: 37.7 s

# %%
# %%time
from snow_pipeline import *
log.getLogger().setLevel(log.DEBUG)

snow_root = Path('~/snow/').expanduser().absolute()
benchmark_datasets = dict(get_snow_datasets(snow_root))
for name, ds in benchmark_datasets.items():
    print(f'{len(ds[0].fnames):3d}', name)

dataset_name = 'www.nndb.com'
ts = list(takco.TableSet.dataset(benchmark_datasets[dataset_name][0]))#[-50:]
print(f"Loaded {dataset_name},  {len(ts)} tables")
# Out:
#  12 d3football.com
#   8 www.vgchartz.com
# 213 www.cia.gov
#  29 www.nndb.com
#   6 flightaware.com
#  76 itunes.apple.com
#  74 seatgeek.com
#  65 www.amoeba.com
#  13 data.bls.gov
# Loaded www.nndb.com,  29 tables
# CPU times: user 4.15 s, sys: 95.5 ms, total: 4.24 s
# Wall time: 4.27 s

# %%
# %%time
tabid_df = preprocess_tables(ts)
# Out:
# Extracting disambguation columns: 100%|██████████| 29/29 [00:01<00:00, 23.57it/s]
# Renaming temporal columns: 100%|██████████| 29/29 [00:01<00:00, 19.28it/s]
# Renaming URI prefix columns: 1it [00:02,  2.20s/it]
# CPU times: user 20.6 s, sys: 36 ms, total: 20.6 s
# Wall time: 20.7 s

# %%
# Which features of these tables can we use to match them?
from snow_pipeline import *

predict_fkclasses(tabid_df, dataset_name, kb)
# for tabid, df in tabid_df.items():
# #     print(tabid, *('|'.join(c) for c in zip(*df.columns)))
#     for c, s in df.iteritems():
#         top = pd.Series(TfidfMatcher._analyzer(s)).value_counts()[:3]
# #         if c[0].startswith('pr'):
#         print(tabid, c, dict(top))
# Out:
# DEBUG:root:[www.nndb.com] [0.json] Class predictions: ['page title:Film/1.24e-01', 'uri 0:Company/3.95e-08', 'name:Artist/6.70e-02', 'occupation:Film/3.94e-07', 'known for:Film/6.37e-02']
# DEBUG:root:[www.nndb.com] [1.json] Class predictions: ['page title:Single/6.90e-04', 'uri 0:Single/3.65e-10', 'name:Person/4.75e-01', 'occupation:Country/3.49e-05', 'known for:Film/3.52e-01']
# DEBUG:root:[www.nndb.com] [10.json] Class predictions: ['page title:VideoGame/1.45e-03', 'uri 0:TelevisionShow/2.45e-07', 'name:Person/3.30e-01', 'occupation:Country/1.05e-03', 'known for:VideoGame/4.02e-01']
# DEBUG:root:[www.nndb.com] [11.json] Class predictions: ['page title:SportsTeam/2.76e-03', 'uri 0:VideoGame/1.34e-06', 'name:Athlete/2.73e-01', 'occupation:SportsTeam/6.26e-04', 'known for:Country/1.69e-01']
# DEBUG:root:[www.nndb.com] [12.json] Class predictions: ['uri 0:Building/3.36e-06', 'name:Person/6.59e-01', 'occupation:Country/4.05e-04', 'known for:Film/8.29e-01']
# DEBUG:root:[www.nndb.com] [13.json] Class predictions: ['page title:Band/2.48e-01', 'uri 0:Company/5.72e-06', 'name:Artist/2.65e-01', 'occupation:Album/1.92e-05', 'known for:Album/2.40e-01']
# DEBUG:root:[www.nndb.com] [14.json] Class predictions: ['page title:Band/5.04e-02', 'uri 0:Company/8.05e-06', 'name:OfficeHolder/4.70e-01', 'occupation:Country/1.68e-04', 'known for:Film/4.70e-01']
# DEBUG:root:[www.nndb.com] [15.json] Class predictions: ['page title:Band/7.92e-03', 'uri 0:Company/3.17e-05', 'name:Person/4.39e-01', 'occupation:Country/1.61e-03', 'known for:VideoGame/5.44e-01']
# DEBUG:root:[www.nndb.com] [16.json] Class predictions: ['page title:SportsTeam/1.59e-03', 'uri 0:Company/2.38e-07', 'company:Company/4.98e-01']
# DEBUG:root:[www.nndb.com] [17.json] Class predictions: ['page title:Company/2.51e-04', 'uri 0:Single/4.11e-08', 'company:Company/3.97e-01']
# DEBUG:root:[www.nndb.com] [18.json] Class predictions: ['page title:SportsTeam/8.42e-03', 'uri 0:Company/4.36e-07', 'school:EducationalInstitution/7.45e-01']
# DEBUG:root:[www.nndb.com] [19.json] Class predictions: ['page title:Country/2.36e-06', 'uri 0:Company/2.14e-07', 'name:Artist/2.41e-01', 'occupation:Country/3.35e-03', 'known for:Film/7.31e-01']
# DEBUG:root:[www.nndb.com] [2.json] Class predictions: ['page title:EducationalInstitution/2.38e-02', 'uri 0:Athlete/1.14e-08', 'name:OfficeHolder/6.47e-01', 'occupation:Country/7.83e-05', 'known for:Country/4.37e-01']
# DEBUG:root:[www.nndb.com] [20.json] Class predictions: ['page title:Band/3.37e-03', 'uri 0:Company/3.80e-06', 'name:OfficeHolder/2.39e-01', 'occupation:Company/2.06e-04', 'known for:Film/4.34e-01']
# DEBUG:root:[www.nndb.com] [21.json] Class predictions: ['page title:Settlement/9.97e-03', 'uri 0:Company/5.41e-06', 'museum:Museum/1.10e+00']
# DEBUG:root:[www.nndb.com] [22.json] Class predictions: ['page title:AdministrativeRegion/2.68e-03', 'uri 0:Company/6.14e-06', 'city:AdministrativeRegion/6.95e-02', 'type:Settlement/1.99e-03']
# DEBUG:root:[www.nndb.com] [23.json] Class predictions: ['page title:Hospital/5.41e-03', 'uri 0:Single/1.35e-06', 'name:Artist/1.34e-01', 'occupation:Country/4.42e-04', 'known for:TelevisionShow/4.02e-01']
# DEBUG:root:[www.nndb.com] [24.json] Class predictions: ['page title:Settlement/5.97e-03', 'uri 0:Building/8.24e-06', 'district:OfficeHolder/1.05e-02', 'representative:Athlete/2.02e-01', 'party:Country/2.19e-04']
# DEBUG:root:[www.nndb.com] [25.json] Class predictions: ['page title:Museum/1.56e-02', 'uri 0:Museum/9.37e-03', 'name:OfficeHolder/2.32e-01', 'occupation:Company/2.77e-03', 'known for:Country/3.86e-01']
# DEBUG:root:[www.nndb.com] [26.json] Class predictions: ['page title:Artist/2.41e-04', 'uri 0:Company/6.71e-05', 'institution:Museum/7.39e-01', 'type:Museum/3.59e-01']
# DEBUG:root:[www.nndb.com] [27.json] Class predictions: ['page title:Country/7.30e-03', 'uri 0:Company/2.16e-04', 'orchestra:Band/4.33e-02']
# DEBUG:root:[www.nndb.com] [28.json] Class predictions: ['page title:SportsTeam/5.04e-04', 'uri 0:Company/6.33e-04', 'venue:Building/9.86e-02']
# DEBUG:root:[www.nndb.com] [3.json] Class predictions: ['page title:Country/1.21e-02', 'uri 0:Company/2.53e-08', 'name:OfficeHolder/5.01e-01', 'occupation:Country/1.28e-04', 'known for:Country/3.11e-01']
# DEBUG:root:[www.nndb.com] [4.json] Class predictions: ['page title:Settlement/3.29e-03', 'uri 0:Company/1.40e-08', 'name:Person/8.15e-01', 'occupation:Country/1.18e-04', 'known for:Film/6.71e-01']
# DEBUG:root:[www.nndb.com] [5.json] Class predictions: ['page title:TelevisionShow/1.03e-01', 'uri 0:TelevisionShow/3.60e-07', 'name:Artist/3.54e-01', 'occupation:TelevisionShow/4.96e-06', 'known for:TelevisionShow/2.61e-01']
# DEBUG:root:[www.nndb.com] [6.json] Class predictions: ['page title:Country/4.81e-03', 'uri 0:EducationalInstitution/2.26e-08', 'name:OfficeHolder/6.02e-01', 'occupation:SportsTeam/2.55e-04', 'known for:Film/5.58e-01']
# DEBUG:root:[www.nndb.com] [7.json] Class predictions: ['page title:Country/1.61e-02', 'uri 0:Building/3.75e-08', 'name:OfficeHolder/6.43e-01', 'occupation:Country/2.33e-04']
# DEBUG:root:[www.nndb.com] [8.json] Class predictions: ['page title:EducationalInstitution/5.64e-04', 'uri 0:VideoGame/3.28e-08', 'name:Person/5.63e-01', 'occupation:Country/9.06e-04', 'known for:Film/5.90e-01']
# DEBUG:root:[www.nndb.com] [9.json] Class predictions: ['page title:Company/4.24e-02', 'uri 0:Company/6.12e-06', 'name:OfficeHolder/5.93e-01', 'occupation:EducationalInstitution/2.51e-04', 'known for:Country/3.42e-01']
# {'0.json': (0, 'Film'),
#  '1.json': (5, 'Person'),
#  '10.json': (9, 'VideoGame'),
#  '11.json': (5, 'Athlete'),
#  '12.json': (9, 'Film'),
#  '13.json': (5, 'Artist'),
#  '14.json': (5, 'OfficeHolder'),
#  '15.json': (9, 'VideoGame'),
#  '16.json': (5, 'Company'),
#  '17.json': (5, 'Company'),
#  '18.json': (5, 'EducationalInstitution'),
#  '19.json': (9, 'Film'),
#  '2.json': (5, 'OfficeHolder'),
#  '20.json': (9, 'Film'),
#  '21.json': (5, 'Museum'),
#  '22.json': (5, 'AdministrativeRegion'),
#  '23.json': (9, 'TelevisionShow'),
#  '24.json': (6, 'Athlete'),
#  '25.json': (9, 'Country'),
#  '26.json': (5, 'Museum'),
#  '27.json': (5, 'Band'),
#  '28.json': (5, 'Building'),
#  '3.json': (5, 'OfficeHolder'),
#  '4.json': (5, 'Person'),
#  '5.json': (5, 'Artist'),
#  '6.json': (5, 'OfficeHolder'),
#  '7.json': (5, 'OfficeHolder'),
#  '8.json': (9, 'Film'),
#  '9.json': (5, 'OfficeHolder')}

# %%
from snow_pipeline import *

matchers = [
    KBClassMatcher(kb, include_context=False, pred_max_threshold=0.9),
    ExactHeadMatcher(include_context=False),
    TfidfMatcher(num_threshold=0.75, min_df=2),
]
agg_func = "KBClassMatcher * @max(ExactHeadMatcher, TfidfMatcher)"
agg_threshold_col = 0

colsim, idpairs = get_colsim_and_codes(
    tabid_df, matchers,
    agg_func=agg_func, 
    agg_threshold_col=agg_threshold_col
)
partcols = cluster_columns(colsim)
partcolid_to_colids = aggr_by_val(partcols.items())
partcolid_to_colids
# Out:
# Getting KBClassMatcher candidates: 100%|██████████| 29/29 [00:32<00:00,  1.12s/it]
# Getting column text: 100%|██████████| 29/29 [00:23<00:00,  1.21it/s]
# Extracting features: 100%|██████████| 269/269 [00:06<00:00, 39.29it/s]
# DEBUG:root:Got (269, 36958) column features. Calculating similarities...
# DEBUG:root:Clustering columns...
# {2: {"0.json~Col5 ('name',)",
#   "1.json~Col5 ('name',)",
#   "10.json~Col5 ('name',)",
#   "11.json~Col5 ('name',)",
#   "12.json~Col5 ('name',)",
#   "13.json~Col5 ('name',)",
#   "14.json~Col5 ('name',)",
#   "15.json~Col5 ('name',)",
#   "19.json~Col5 ('name',)",
#   "2.json~Col5 ('name',)",
#   "20.json~Col5 ('name',)",
#   "23.json~Col5 ('name',)",
#   "24.json~Col6 ('representative',)",
#   "25.json~Col5 ('name',)",
#   "3.json~Col5 ('name',)",
#   "4.json~Col5 ('name',)",
#   "5.json~Col5 ('name',)",
#   "6.json~Col5 ('name',)",
#   "7.json~Col5 ('name',)",
#   "8.json~Col5 ('name',)",
#   "9.json~Col5 ('name',)"},
#  4: {"0.json~Col6 ('occupation',)",
#   "1.json~Col6 ('occupation',)",
#   "10.json~Col6 ('occupation',)",
#   "11.json~Col6 ('occupation',)",
#   "12.json~Col6 ('occupation',)",
#   "13.json~Col6 ('occupation',)",
#   "14.json~Col6 ('occupation',)",
#   "15.json~Col6 ('occupation',)",
#   "19.json~Col6 ('occupation',)",
#   "2.json~Col6 ('occupation',)",
#   "20.json~Col6 ('occupation',)",
#   "23.json~Col6 ('occupation',)",
#   "25.json~Col6 ('occupation',)",
#   "3.json~Col6 ('occupation',)",
#   "4.json~Col6 ('occupation',)",
#   "5.json~Col6 ('occupation',)",
#   "6.json~Col6 ('occupation',)",
#   "7.json~Col6 ('occupation',)",
#   "8.json~Col6 ('occupation',)",
#   "9.json~Col6 ('occupation',)"},
#  3: {"0.json~Col7 ('birth',)",
#   "1.json~Col7 ('birth',)",
#   "10.json~Col7 ('birth',)",
#   "11.json~Col7 ('birth',)",
#   "12.json~Col7 ('birth',)",
#   "13.json~Col7 ('birth',)",
#   "14.json~Col7 ('birth',)",
#   "15.json~Col7 ('birth',)",
#   "19.json~Col7 ('birth',)",
#   "2.json~Col7 ('birth',)",
#   "20.json~Col7 ('birth',)",
#   "23.json~Col7 ('birth',)",
#   "25.json~Col7 ('birth',)",
#   "3.json~Col7 ('birth',)",
#   "4.json~Col7 ('birth',)",
#   "5.json~Col7 ('birth',)",
#   "6.json~Col7 ('birth',)",
#   "7.json~Col7 ('birth',)",
#   "8.json~Col7 ('birth',)",
#   "9.json~Col7 ('birth',)"},
#  5: {"0.json~Col8 ('death',)",
#   "1.json~Col8 ('death',)",
#   "10.json~Col8 ('death',)",
#   "11.json~Col8 ('death',)",
#   "12.json~Col8 ('death',)",
#   "13.json~Col8 ('death',)",
#   "14.json~Col8 ('death',)",
#   "15.json~Col8 ('death',)",
#   "19.json~Col8 ('death',)",
#   "2.json~Col8 ('death',)",
#   "20.json~Col8 ('death',)",
#   "23.json~Col8 ('death',)",
#   "25.json~Col8 ('death',)",
#   "3.json~Col8 ('death',)",
#   "4.json~Col8 ('death',)",
#   "5.json~Col8 ('death',)",
#   "6.json~Col8 ('death',)",
#   "7.json~Col8 ('death',)",
#   "8.json~Col8 ('death',)",
#   "9.json~Col8 ('death',)"},
#  7: {"0.json~Col9 ('known for',)",
#   "1.json~Col9 ('known for',)",
#   "10.json~Col9 ('known for',)",
#   "11.json~Col9 ('known for',)",
#   "12.json~Col9 ('known for',)",
#   "13.json~Col9 ('known for',)",
#   "14.json~Col9 ('known for',)",
#   "15.json~Col9 ('known for',)",
#   "19.json~Col9 ('known for',)",
#   "2.json~Col9 ('known for',)",
#   "20.json~Col9 ('known for',)",
#   "23.json~Col9 ('known for',)",
#   "25.json~Col9 ('known for',)",
#   "3.json~Col9 ('known for',)",
#   "4.json~Col9 ('known for',)",
#   "5.json~Col9 ('known for',)",
#   "6.json~Col9 ('known for',)",
#   "7.json~Col9 ('known for',)",
#   "8.json~Col9 ('known for',)",
#   "9.json~Col9 ('known for',)"},
#  0: {"16.json~Col5 ('company',)",
#   "17.json~Col5 ('company',)",
#   "18.json~Col5 ('school',)",
#   "21.json~Col5 ('museum',)",
#   "22.json~Col5 ('city',)",
#   "26.json~Col5 ('institution',)"},
#  6: {"16.json~Col6 ('founded',)",
#   "18.json~Col6 ('founded',)",
#   "21.json~Col6 ('founded',)",
#   "26.json~Col7 ('founded',)",
#   "27.json~Col6 ('founded',)",
#   "28.json~Col6 ('founded',)"},
#  11: {"17.json~Col6 ('sales',)"},
#  8: {"22.json~Col6 ('type',)", "26.json~Col6 ('type',)"},
#  9: {"24.json~Col5 ('district',)"},
#  10: {"24.json~Col8 ('party',)"},
#  1: {"27.json~Col5 ('orchestra',)", "28.json~Col5 ('venue',)"}}

# %%
partid_to_tabids = partition_connected_components(tabid_df, partcolid_to_colids, idpairs)
for partid, tis in partid_to_tabids.items():
    print(f"part-{partid}", len(tis), tis)
# Out:
# part-0 21 {'4.json', '23.json', '0.json', '12.json', '1.json', '11.json', '14.json', '20.json', '13.json', '3.json', '2.json', '5.json', '9.json', '8.json', '19.json', '25.json', '15.json', '6.json', '24.json', '10.json', '7.json'}
# part-1 8 {'17.json', '27.json', '22.json', '21.json', '26.json', '18.json', '28.json', '16.json'}

# %%
from snow_pipeline import *

stitched = stitch_colclustered_tables(tabid_df, partcols, idpairs)
stitched_df = {}
for partid, (df, cols) in enumerate(stitched):
    df.columns = pd.MultiIndex.from_tuples(cols)
    stitched_df[f"part-{partid}"] = df
    print(*zip(*cols))
    display( df.sample( min(5, len(df)) ) )
#     if len(df.columns) > 10:
#         break
# Out:
# DEBUG:root:Stitching 21 aligned tables
# ('page title', 'table heading', 'uri 0', 'uri 1', 'uri 2', 'name', 'occupation', 'birth', 'death', 'known for', 'district', 'since', 'party')
#                       page title table heading  uri 0 uri 1      uri 2  \
# 81461       murder on flight 502                films   860  000205245
# 25376  risk factor: lyme disease                lists   101  000369988
# 2393                      exodus                films   701  000035596
# 1620                    burglary                crime   314  000047173
# 39093       occupation: sculptor                lists   332  000096044
#
#                    name occupation        birth        death  \
# 81461     ralph bellamy      actor  17-jun-1904  29-nov-1991
# 25376      richard gere      actor  31-aug-1949
# 2393          sal mineo      actor  10-jan-1939  12-feb-1976
# 1620          ryan leaf   football  15-may-1976
# 39093  aristide maillol   sculptor   8-apr-1861  27-sep-1944
#
#                            known for district since party
# 81461                 trading places      NaN   NaN   NaN
# 25376                american gigolo      NaN   NaN   NaN
# 2393   dies in rebel without a cause      NaN   NaN   NaN
# 1620   disappointing nfl quarterback      NaN   NaN   NaN
# 39093    sculptor of the female nude      NaN   NaN   NaN
# DEBUG:root:Stitching 8 aligned tables
# ('page title', 'table heading', 'uri 0', 'uri 1', 'uri 2', 'company', 'founded', 'sales', 'employees', 'disambiguation of sales (year)', 'type', 'population', 'orchestra')
#                  page title table heading  uri 0 uri 1      uri 2  \
# 3           springfield, ma                  geo   724  000069517
# 614        philadelphia, pa                  geo   659  000069452
# 787             houston, tx                  geo   540  000069333
# 80   sector: communications                lists   628  000098334
# 91            charlotte, nc                  geo   453  000069246
#
#                             company founded sales employees  \
# 3    american international college    1885   NaN       NaN
# 614                     dechert llp    1875   NaN       NaN
# 787                 quanta services    1997   NaN       NaN
# 80                        bellsouth     NaN
# 91      johnson c. smith university    1867   NaN       NaN
#
#     disambiguation of sales (year) type population orchestra
# 3                              NaN  NaN        NaN       NaN
# 614                            NaN  NaN        NaN       NaN
# 787                            NaN  NaN        NaN       NaN
# 80                             NaN  NaN        NaN       NaN
# 91                             NaN  NaN        NaN       NaN

# %%
df = stitched_df['part-0']
print(len(df))
sim = kb.get_sim(df)
display(df.describe().T)
pred = pd.DataFrame({"column": list(df.columns[list(sim.columns)]), "class": sim.idxmax(), "score": sim.max()})
display( pred.style.background_gradient() )
# Out:
# 227226
#                 count unique                         top    freq
# page title     227226  22007  university of pennsylvania     523
# table heading  227226      1                              227226
# uri 0          227226     20                       films  104010
# uri 1          227226    997                         640    1114
# uri 2          227226  22791                   000068313     523
# name           227226  37563           donald sutherland      82
# occupation     227180    164                       actor  117879
# birth          227180  23854                                 951
# death          227180  13018                              130437
# known for      227180  34338    american character actor     625
# district           46      9                         1st      10
# since              46     16                        2011      12
# party              46      2                  republican      29
# <style  type="text/css" >
# #T_53c41_row0_col2{
#             background-color:  #96b6d7;
#             color:  #000000;
#         }#T_53c41_row1_col2,#T_53c41_row2_col2,#T_53c41_row4_col2{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_53c41_row3_col2{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_53c41_row5_col2{
#             background-color:  #04649e;
#             color:  #f1f1f1;
#         }</style><table id="T_53c41_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >column</th>        <th class="col_heading level0 col1" >class</th>        <th class="col_heading level0 col2" >score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_53c41_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_53c41_row0_col0" class="data row0 col0" >('page title',)</td>
#                         <td id="T_53c41_row0_col1" class="data row0 col1" >Film</td>
#                         <td id="T_53c41_row0_col2" class="data row0 col2" >0.050354</td>
#             </tr>
#             <tr>
#                         <th id="T_53c41_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_53c41_row1_col0" class="data row1 col0" >('table heading',)</td>
#                         <td id="T_53c41_row1_col1" class="data row1 col1" >Hospital</td>
#                         <td id="T_53c41_row1_col2" class="data row1 col2" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_53c41_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_53c41_row2_col0" class="data row2 col0" >('uri 0',)</td>
#                         <td id="T_53c41_row2_col1" class="data row2 col1" >Company</td>
#                         <td id="T_53c41_row2_col2" class="data row2 col2" >0.000001</td>
#             </tr>
#             <tr>
#                         <th id="T_53c41_level0_row3" class="row_heading level0 row3" >5</th>
#                         <td id="T_53c41_row3_col0" class="data row3 col0" >('name',)</td>
#                         <td id="T_53c41_row3_col1" class="data row3 col1" >Person</td>
#                         <td id="T_53c41_row3_col2" class="data row3 col2" >0.121111</td>
#             </tr>
#             <tr>
#                         <th id="T_53c41_level0_row4" class="row_heading level0 row4" >6</th>
#                         <td id="T_53c41_row4_col0" class="data row4 col0" >('occupation',)</td>
#                         <td id="T_53c41_row4_col1" class="data row4 col1" >Country</td>
#                         <td id="T_53c41_row4_col2" class="data row4 col2" >0.000002</td>
#             </tr>
#             <tr>
#                         <th id="T_53c41_level0_row5" class="row_heading level0 row5" >9</th>
#                         <td id="T_53c41_row5_col0" class="data row5 col0" >('known for',)</td>
#                         <td id="T_53c41_row5_col1" class="data row5 col1" >Film</td>
#                         <td id="T_53c41_row5_col2" class="data row5 col2" >0.098536</td>
#             </tr>
#     </tbody></table>

# %%
tabid_to_colnr_and_fkclass = predict_fkclasses(stitched_df, dataset_name, kb)
tabid_to_colnr_and_fkclass
# Out:
# DEBUG:root:[www.nndb.com] [part-0] Class predictions: ['page title:Film/5.04e-02', 'uri 0:Company/1.34e-06', 'name:Person/1.21e-01', 'occupation:Country/1.72e-06', 'known for:Film/9.85e-02']
# DEBUG:root:[www.nndb.com] [part-1] Class predictions: ['page title:Company/3.22e-03', 'uri 0:Company/1.86e-07', 'company:EducationalInstitution/5.49e-01']
# {'part-0': (5, 'Person'), 'part-1': (5, 'EducationalInstitution')}

# %%
nary_induction = True
decomposed = iter_decomposed(
    stitched_df, 
    dataset_name, 
    tabid_to_colnr_and_fkclass, 
    nary=nary_induction, 
    nary_stoplevel=2,
    nary_minp= 0.95
)
for t in postprocess_tables(decomposed, numeric_threshold=0.5):
    print(f"{t._id}: {len(t.df)} rows")
    display( t.df.sample(min(len(t.df), 3)) )
# Out:
# DEBUG:root:[itunes.apple.com] [part-0] Decomposing class Single for col 10 (('nome',))
# DEBUG:root:[itunes.apple.com] [part-0] Not decomposing context columns [('page title',), ('uri 1 (se)',), ('disambiguation of name',), ('table heading',), ('disambiguation of album',), ('uri 0',), ('uri 3',), ('uri 2 (album)',), ('uri 1 (music video)',), ('uri 2 (music video)',), ('uri 2 (artist)',), ('uri 2',), ('uri 1',), ('uri 1 (gb)',), ('uri 1 (podcast)',), ('uri 2 (podcast)',), ('disambiguation of page title',), ('uri 1 (hn)',)]
# DEBUG:root:[itunes.apple.com] [part-0] Inferring FDs for [page title|NULL|duração|uri 0|uri 2 (album)|preço|artista|FK|name|album|interpret|álbum]
# FD candidates:  46%|████▋     | 31/67 [00:29<00:27,  1.30it/s]
