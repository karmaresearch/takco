# %%
import sys
import pandas
import trident
import collections
import elasticsearch
import numpy as np

# %% [markdown]
# ## Params

# %%
csv_triples = '/export/scratch1/home/urbani/results/22mar-t2dv2-dbpedia2014/triples/gold/extracted_triples-GOLD.csv' # Example file
trident_dbpedia = '/export/scratch1/home/urbani/data2/dbpedia2014'
embeddings_dbpedia = '/export/scratch1/home/urbani/data2/dbpedia_embeddings/model-500'
elastic_endpoint = 'localhost:9999'
prefix_dbpedia = 'http://dbpedia.org/resource/'

# %% [markdown]
# ## Load various inputs

# %%
tables = pandas.read_csv(csv_triples)
nrows = len(tables.index)
print(tables.columns.values)
# Out:
# ['URL' 'Table' 'Column Index' 'Subject URI' 'Subject Value'
#  'Subject Confidence' 'Predicate URI' 'Predicate Value'
#  'Predicate Confidence' 'Data Type' 'Object Value' 'Object Value in KB'
#  'Object Value matches KB' 'Object Value Similarity']

# %%
db = trident.Db(trident_dbpedia)
es = elasticsearch.Elasticsearch()

# %%
label_id = db.lookup_relid('<http://www.w3.org/2000/01/rdf-schema#label>')
print(label_id)
# Out:
# 15

# %%
emb = trident.Emb(embeddings_dbpedia)

# %% [markdown]
# ## Function to disambiguate the triples

# %%
TableResults = collections.namedtuple('TableResults', 'redundant novel errors numeric')
#redundant= number of triples which are already in the KB (and we can verify this easily)
#novel= triples which we can correctly disambiguate and are not in the KB
#errors=triples which are not in the KB but for which we cannot extract a suitable entity (e.g., the KB does not contain suitable labels, etc.)

# %%
def getCandidatesFromElasticSearch(entity_label):
    results = []
    try:
        out = es.search(index="dbpedia2014part_intl_labels_labeldocs", body={"query": {"match": {'label': entity_label}}})
        # I only get the top 10 hits at most. They should be enough
        out = out['hits']['hits']
        for hit in out:
            source = hit['_source']
            ids = source['ids']
            for ent in ids:
                full_ent =  '<' + prefix_dbpedia + ent + '>'
                id_ent = db.lookup_id(full_ent)
                if id_ent is not None:
                    results.append(id_ent)
                else:
                    pass                
    except Exception as e:
        print("Failed getting candidates from the KB for", entity_label, " error", str(e))
    if len(results) == 0:
        return None
    else:
        return results

# %%
def isNumeric(label):
    if type(label) == float:
        return True
    return label.isdigit()

# %%
def processTriples(triples):
    redundant = 0 
    novel = 0 
    errors = 0
    numeric = 0
    
    for triple in triples:
        # Get the ID for the subject
        subject_str = triple[0]
        subject_id = db.lookup_id('<' + subject_str + '>')
        if subject_id is None:
            print("Warning, I cannot find an ID for the resource", subject_str)
            continue
        # Get the ID for the predicate
        predicate_str = triple[1]
        predicate_id = db.lookup_relid('<' + predicate_str + '>')
        if predicate_id is None:
            print("Warning, I cannot find an ID for the resource", predicate_str)
            continue        
        # Get the label of the object
        object_label = triple[2]
        
        # Before we continue, we check whether the KB has already an object for the give s,p
        found_obj = False
        found_errors = False
        is_numeric = False
        
        objects_kb = db.o(subject_id, predicate_id)
        if len(objects_kb) > 0:            
            # Get the labels of the objects
            for object_kb in objects_kb:
                object_kb_ent = db.lookup_str(object_kb)
                if object_kb_ent is not None:
                    object_kb_label = db.o(object_kb, label_id)
                    if len(object_kb_label) > 0:                        
                        found_label = db.lookup_str(object_kb_label[0])
                        if found_label is not None:
                            # TODO: check the two strings are sufficiently similar
                            #print(found_label, object_label)
                            found_obj = True
                            break
                    else:
                        #print("Cannot get the label for", object_kb_ent)
                        found_errors = True
                        break                    
            
        if not found_errors and not found_obj:            
            #First check whether the string is not a numeral or a date
            if isNumeric(object_label):
                is_numeric = True
            else:            
                # If it is not, get some potential candidate from elastic search
                candidates = getCandidatesFromElasticSearch(object_label)
                if candidates is not None:
                    top_cand_before_ranking = candidates[0]
                    # Rank the top-k candidates
                    candidates = rank(subject_id, predicate_id, candidates)
                    top_cand_after_ranking = candidates[0]
                    chosen_candidate = db.lookup_str(top_cand_after_ranking)
                    if top_cand_before_ranking != top_cand_after_ranking:
                        print(subject_str, predicate_str)
                        print(db.lookup_str(top_cand_before_ranking), db.lookup_str(top_cand_after_ranking))
                else:
                    found_errors = True
        
        # Increase the counters
        if found_errors:
            errors += 1
        elif is_numeric:
            numeric += 1
        elif not found_obj:
            novel += 1
        else:
            redundant += 1
    return TableResults(novel=novel, redundant=redundant, errors=errors, numeric=numeric)

# %%
def rank(subj, pred, candidates):
    rankedList = []
    # Get the embedding of the subject
    emb_s = emb.get_e(subj)
    # Get the embedding of the predicate
    emb_r = emb.get_r(pred)
    emb_sum = emb_s + emb_r
    k = 0
    for candidate in candidates:
        # Get the embedding of the candidate
        emb_cand = emb.get_e(candidate)
        # Measure the similarity
        sim = np.sum(np.abs(emb_sum - emb_cand))
        #print(sim, candidate, db.lookup_str(candidate))
        rankedList.append((sim, candidate))
        # Only consider the top-10 candidates
        k += 1        
        if k == 10:
            break
    # Sort the list
    rankedList.sort()
    #if rankedList[0][1] != candidates[0]:
    #    print(db.lookup_str(subj), db.lookup_relstr(pred))
    #    print("was", db.lookup_str(candidates[0]), "now", db.lookup_str(rankedList[0][1]))
    candidates = [can for (sim, can) in rankedList]            
    return candidates

# %% [markdown]
# ## Disambiguate the objects

# %%
tidx = 0
for tname, table in tables.groupby('Table'):
    print("Processing table", tidx, tname)
    triples = []
    for rdix, row in table.iterrows():         
        triple = (row['Subject URI'], row['Predicate URI'], row['Object Value'])
        triples.append(triple)        
    print(processTriples(triples))
    tidx += 1
    if tidx >= 10:
        break # For now, just disambiguate one table
# Out:
# Processing table 0 10151359_0_8168779773862259178.csv
# TableResults(redundant=238, novel=2, errors=6, numeric=0)
# Processing table 1 10630177_0_4831842476649004753.csv
# http://dbpedia.org/resource/Princess_Tower http://dbpedia.org/ontology/location
# <http://dbpedia.org/resource/Dubai_Municipality> <http://dbpedia.org/resource/Dubai>
# http://dbpedia.org/resource/Al_Yaqoub_Tower http://dbpedia.org/ontology/location
# <http://dbpedia.org/resource/Dubai_Municipality> <http://dbpedia.org/resource/Dubai>
# http://dbpedia.org/resource/Eureka_Tower http://dbpedia.org/ontology/location
# <http://dbpedia.org/resource/Division_of_Melbourne> <http://dbpedia.org/resource/Melbourne_City_Centre>
# http://dbpedia.org/resource/China_World_Trade_Center_Tower_III http://dbpedia.org/ontology/location
# <http://dbpedia.org/resource/SS_City_of_Peking> <http://dbpedia.org/resource/Beijing>
# http://dbpedia.org/resource/Princess_Tower http://dbpedia.org/ontology/location
# <http://dbpedia.org/resource/Dubai_Municipality> <http://dbpedia.org/resource/Dubai>
# http://dbpedia.org/resource/Al_Yaqoub_Tower http://dbpedia.org/ontology/location
# <http://dbpedia.org/resource/Dubai_Municipality> <http://dbpedia.org/resource/Dubai>
# http://dbpedia.org/resource/Eureka_Tower http://dbpedia.org/ontology/location
# <http://dbpedia.org/resource/Division_of_Melbourne> <http://dbpedia.org/resource/Melbourne_City_Centre>
# http://dbpedia.org/resource/China_World_Trade_Center_Tower_III http://dbpedia.org/ontology/location
# <http://dbpedia.org/resource/SS_City_of_Peking> <http://dbpedia.org/resource/Beijing>
# http://dbpedia.org/resource/Columbia_Center http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/UTC+01:00> <http://dbpedia.org/resource/'00>
# http://dbpedia.org/resource/70_Pine_Street http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/UTC+01:00> <http://dbpedia.org/resource/'00>
# http://dbpedia.org/resource/Central_Plaza_(Hong_Kong) http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/1992> <http://dbpedia.org/resource/UTC+01:00>
# http://dbpedia.org/resource/Haeundae_I_Park_Marina http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/UTC+01:00> <http://dbpedia.org/resource/'00>
# http://dbpedia.org/resource/Transamerica_Pyramid http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/UTC+01:00> <http://dbpedia.org/resource/'00>
# http://dbpedia.org/resource/Franklin_Center_(Chicago) http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/UTC+01:00> <http://dbpedia.org/resource/'00>
# http://dbpedia.org/resource/GE_Building http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/UTC+01:00> <http://dbpedia.org/resource/'00>
# http://dbpedia.org/resource/Citigroup_Center http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/UTC+01:00> <http://dbpedia.org/resource/'00>
# http://dbpedia.org/resource/Bank_of_America_Corporate_Center http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/1992> <http://dbpedia.org/resource/'00>
# http://dbpedia.org/resource/U.S._Steel_Tower http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/UTC+01:00> <http://dbpedia.org/resource/Unix_time>
# http://dbpedia.org/resource/First_Canadian_Place http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/UTC+01:00> <http://dbpedia.org/resource/'00>
# http://dbpedia.org/resource/SunTrust_Plaza http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/1992> <http://dbpedia.org/resource/UTC+01:00>
# http://dbpedia.org/resource/Bank_of_America_Plaza_(Dallas) http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/UTC+01:00> <http://dbpedia.org/resource/'00>
# http://dbpedia.org/resource/120_Collins_Street http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/1991> <http://dbpedia.org/resource/UTC+01:00>
# http://dbpedia.org/resource/Yokohama_Landmark_Tower http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/1993> <http://dbpedia.org/resource/UTC+01:00>
# http://dbpedia.org/resource/Chase_Tower_(Chicago) http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/UTC+01:00> <http://dbpedia.org/resource/'00>
# http://dbpedia.org/resource/Liberty_Place http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/UTC+01:00> <http://dbpedia.org/resource/'00>
# http://dbpedia.org/resource/Haeundae_I_Park_Marina http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/UTC+01:00> <http://dbpedia.org/resource/'00>
# http://dbpedia.org/resource/Key_Tower http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/1991> <http://dbpedia.org/resource/UTC+01:00>
# http://dbpedia.org/resource/UOB_Plaza http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/1992> <http://dbpedia.org/resource/UTC+01:00>
# http://dbpedia.org/resource/U.S._Bank_Tower_(Los_Angeles) http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/UTC+01:00> <http://dbpedia.org/resource/'00>
# http://dbpedia.org/resource/Keangnam_Hanoi_Landmark_Tower http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/UTC+01:00> <http://dbpedia.org/resource/'00>
# http://dbpedia.org/resource/101_Collins_Street http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/1991> <http://dbpedia.org/resource/UTC+01:00>
# http://dbpedia.org/resource/21st_Century_Tower http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/UTC+01:00> <http://dbpedia.org/resource/'00>
# http://dbpedia.org/resource/Chrysler_Building http://dbpedia.org/ontology/openingDate
# <http://dbpedia.org/resource/UTC+01:00> <http://dbpedia.org/resource/'00>
# TableResults(redundant=336, novel=175, errors=356, numeric=0)
# Processing table 2 11278409_0_3742771475298785475.csv
# http://dbpedia.org/resource/Food_Lion http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/List_of_supermarket_chains> <http://dbpedia.org/resource/Grocery_store>
# http://dbpedia.org/resource/Piggly_Wiggly http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/List_of_supermarket_chains> <http://dbpedia.org/resource/Grocery_store>
# http://dbpedia.org/resource/Verizon_Wireless http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/Mobile_network_operator> <http://dbpedia.org/resource/Wireless_LAN>
# http://dbpedia.org/resource/Charles_Schwab_Corporation http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/Investment_company> <http://dbpedia.org/resource/Financial_adviser>
# http://dbpedia.org/resource/Citibank http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/Bank_(card_game)> <http://dbpedia.org/resource/Stratum>
# http://dbpedia.org/resource/Arby's http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/Fast_food_restaurant> <http://dbpedia.org/resource/Fast_food>
# http://dbpedia.org/resource/T-Mobile http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/Mobile_network_operator> <http://dbpedia.org/resource/Wireless_LAN>
# http://dbpedia.org/resource/Sears http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/Retail> <http://dbpedia.org/resource/Grocery_store>
# http://dbpedia.org/resource/Bright_House_Networks http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/Service_provider> <http://dbpedia.org/resource/Internet_service_provider>
# http://dbpedia.org/resource/Save-A-Lot http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/List_of_supermarket_chains> <http://dbpedia.org/resource/Grocery_store>
# http://dbpedia.org/resource/Citizens_Financial_Group http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/Bank_(card_game)> <http://dbpedia.org/resource/Stratum>
# http://dbpedia.org/resource/Food_Lion http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/List_of_supermarket_chains> <http://dbpedia.org/resource/Grocery_store>
# http://dbpedia.org/resource/Piggly_Wiggly http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/List_of_supermarket_chains> <http://dbpedia.org/resource/Grocery_store>
# http://dbpedia.org/resource/Verizon_Wireless http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/Mobile_network_operator> <http://dbpedia.org/resource/Wireless_LAN>
# http://dbpedia.org/resource/Charles_Schwab_Corporation http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/Investment_company> <http://dbpedia.org/resource/Financial_adviser>
# http://dbpedia.org/resource/Citibank http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/Bank_(card_game)> <http://dbpedia.org/resource/Stratum>
# http://dbpedia.org/resource/Arby's http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/Fast_food_restaurant> <http://dbpedia.org/resource/Fast_food>
# http://dbpedia.org/resource/T-Mobile http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/Mobile_network_operator> <http://dbpedia.org/resource/Wireless_LAN>
# http://dbpedia.org/resource/Sears http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/Retail> <http://dbpedia.org/resource/Grocery_store>
# http://dbpedia.org/resource/Bright_House_Networks http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/Service_provider> <http://dbpedia.org/resource/Internet_service_provider>
# http://dbpedia.org/resource/Save-A-Lot http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/List_of_supermarket_chains> <http://dbpedia.org/resource/Grocery_store>
# http://dbpedia.org/resource/Citizens_Financial_Group http://dbpedia.org/ontology/industry
# <http://dbpedia.org/resource/Bank_(card_game)> <http://dbpedia.org/resource/Stratum>
# TableResults(redundant=332, novel=44, errors=0, numeric=0)
# Processing table 3 1146722_1_7558140036342906956.csv
# TableResults(redundant=0, novel=0, errors=430, numeric=0)
# Processing table 4 11599512_1_280388135214354946.csv
# http://dbpedia.org/resource/Sierra_Leone http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Barbados http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Centrale_(Croydon)> <http://dbpedia.org/resource/Central_Administrative_Okrug>
# http://dbpedia.org/resource/Tanzania http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Guyana http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Arrondissements_of_the_Corse-du-Sud_department> <http://dbpedia.org/resource/South_Australia>
# http://dbpedia.org/resource/England http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/Northern_Europe>
# http://dbpedia.org/resource/Malta http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Romania http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Guernsey http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/Northern_Europe>
# http://dbpedia.org/resource/Suriname http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Arrondissements_of_the_Corse-du-Sud_department> <http://dbpedia.org/resource/South_Australia>
# http://dbpedia.org/resource/Socialist_Federal_Republic_of_Yugoslavia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/Northern_Europe>
# http://dbpedia.org/resource/Latvia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Ukraine http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Chile http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Arrondissements_of_the_Corse-du-Sud_department> <http://dbpedia.org/resource/South_Australia>
# http://dbpedia.org/resource/Slovakia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Libya http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Niger http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Morocco http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Paraguay http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Arrondissements_of_the_Corse-du-Sud_department> <http://dbpedia.org/resource/South_Australia>
# http://dbpedia.org/resource/Kenya http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Egypt http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Netherlands http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/Europe_(dinghy)>
# http://dbpedia.org/resource/Slovenia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Republic_of_the_Congo http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/South_Africa http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Kyrgyzstan http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/Singapore http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia-Pacific>
# http://dbpedia.org/resource/United_States http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/North_Island_(Mangrove_Islands)> <http://dbpedia.org/resource/North_Island>
# http://dbpedia.org/resource/Guinea-Bissau http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Japan http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/Ethiopia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Saint_Lucia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Centrale_(Croydon)> <http://dbpedia.org/resource/Centrale_Region,_Togo>
# http://dbpedia.org/resource/Swaziland http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Burundi http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Costa_Rica http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Centrale_(Croydon)> <http://dbpedia.org/resource/Centrale_Region,_Togo>
# http://dbpedia.org/resource/Scotland http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/Europe_(dinghy)>
# http://dbpedia.org/resource/Falkland_Islands http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Arrondissements_of_the_Corse-du-Sud_department> <http://dbpedia.org/resource/South_Australia>
# http://dbpedia.org/resource/Andorra http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Vanuatu http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Anie> <http://dbpedia.org/resource/Combined_oral_contraceptive_pill>
# http://dbpedia.org/resource/Tuvalu http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Anie> <http://dbpedia.org/resource/Oklahoma_City>
# http://dbpedia.org/resource/Grenada http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Centrale_(Croydon)> <http://dbpedia.org/resource/Centrale_Region,_Togo>
# http://dbpedia.org/resource/Bolivia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Arrondissements_of_the_Corse-du-Sud_department> <http://dbpedia.org/resource/South_Australia>
# http://dbpedia.org/resource/Ghana http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Togo http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Georgia_(country) http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/Federated_States_of_Micronesia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Anie> <http://dbpedia.org/resource/Combined_oral_contraceptive_pill>
# http://dbpedia.org/resource/Dominican_Republic http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Centrale_(Croydon)> <http://dbpedia.org/resource/Centrale_Region,_Togo>
# http://dbpedia.org/resource/Tunisia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Guatemala http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Centrale_(Croydon)> <http://dbpedia.org/resource/Centrale_Region,_Togo>
# http://dbpedia.org/resource/Gibraltar http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Saint_Vincent_and_the_Grenadines http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Centrale_(Croydon)> <http://dbpedia.org/resource/Centrale_Region,_Togo>
# http://dbpedia.org/resource/French_Polynesia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Anie> <http://dbpedia.org/resource/Combined_oral_contraceptive_pill>
# http://dbpedia.org/resource/Burma http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Southeast_Asia>
# http://dbpedia.org/resource/Afghanistan http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Southeast_Asia>
# http://dbpedia.org/resource/Rwanda http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Sweden http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/Northern_Europe>
# http://dbpedia.org/resource/Equatorial_Guinea http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Czech_Republic http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Sri_Lanka http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/Croatia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Mexico http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/North_Island_(Mangrove_Islands)> <http://dbpedia.org/resource/North_Island>
# http://dbpedia.org/resource/Philippines http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Southeast_Asia>
# http://dbpedia.org/resource/Ecuador http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Arrondissements_of_the_Corse-du-Sud_department> <http://dbpedia.org/resource/South_Australia>
# http://dbpedia.org/resource/Benin http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Tajikistan http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/Norway http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Guinea http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Mauritania http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Luxembourg http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Laos http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Southeast_Asia>
# http://dbpedia.org/resource/Solomon_Islands http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Anie> <http://dbpedia.org/resource/Oklahoma_City>
# http://dbpedia.org/resource/Panama http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Centrale_(Croydon)> <http://dbpedia.org/resource/Centrale_Region,_Togo>
# http://dbpedia.org/resource/Pakistan http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/Djibouti http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Maldives http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/The_Gambia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Malaysia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/Bulgaria http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Ivory_Coast http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Belize http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Centrale_(Croydon)> <http://dbpedia.org/resource/Centrale_Region,_Togo>
# http://dbpedia.org/resource/Somalia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Brazil http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Arrondissements_of_the_Corse-du-Sud_department> <http://dbpedia.org/resource/South_Australia>
# http://dbpedia.org/resource/Mozambique http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Austria http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Nauru http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Anie> <http://dbpedia.org/resource/Combined_oral_contraceptive_pill>
# http://dbpedia.org/resource/Lithuania http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Sudan http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Greenland http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/North_Island_(Mangrove_Islands)> <http://dbpedia.org/resource/North_Island,_Seychelles>
# http://dbpedia.org/resource/Macau http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/Germany http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Bosnia_and_Herzegovina http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Republic_of_Macedonia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/Northern_Europe>
# http://dbpedia.org/resource/Burkina_Faso http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Azerbaijan http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/France http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Samoa http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Anie> <http://dbpedia.org/resource/Combined_oral_contraceptive_pill>
# http://dbpedia.org/resource/Antigua_and_Barbuda http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Centrale_(Croydon)> <http://dbpedia.org/resource/Centrale_Region,_Togo>
# http://dbpedia.org/resource/Republic_of_Ireland http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/Northern_Europe>
# http://dbpedia.org/resource/Belarus http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Venezuela http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Arrondissements_of_the_Corse-du-Sud_department> <http://dbpedia.org/resource/South_Australia>
# http://dbpedia.org/resource/North_Korea http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/Senegal http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Portugal http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Sark http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/Northern_Europe>
# http://dbpedia.org/resource/Peru http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Arrondissements_of_the_Corse-du-Sud_department> <http://dbpedia.org/resource/South_Australia>
# http://dbpedia.org/resource/Finland http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Honduras http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Centrale_(Croydon)> <http://dbpedia.org/resource/Centrale_Region,_Togo>
# http://dbpedia.org/resource/Dominica http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Centrale_(Croydon)> <http://dbpedia.org/resource/Centrale_Region,_Togo>
# http://dbpedia.org/resource/Angola http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Bangladesh http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/Cape_Verde http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Haiti http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Centrale_(Croydon)> <http://dbpedia.org/resource/Centrale_Region,_Togo>
# http://dbpedia.org/resource/Mongolia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/Estonia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Belgium http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Brunei http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Southeast_Asia>
# http://dbpedia.org/resource/Albania http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/Northern_Europe>
# http://dbpedia.org/resource/Easter_Island http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Arrondissements_of_the_Corse-du-Sud_department> <http://dbpedia.org/resource/South_Australia>
# http://dbpedia.org/resource/Chad http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Central_African_Republic http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Papua_New_Guinea http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Southeast_Asia>
# http://dbpedia.org/resource/Namibia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Serbia_and_Montenegro http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Malawi http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Turkey http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/Cambodia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Southeast_Asia>
# http://dbpedia.org/resource/French_Guiana http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Arrondissements_of_the_Corse-du-Sud_department> <http://dbpedia.org/resource/Corse-du-Sud>
# http://dbpedia.org/resource/Moldova http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/Northern_Europe>
# http://dbpedia.org/resource/Switzerland http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Liechtenstein http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/Northern_Europe>
# http://dbpedia.org/resource/The_Bahamas http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Centrale_(Croydon)> <http://dbpedia.org/resource/Centrale_Region,_Togo>
# http://dbpedia.org/resource/Kiribati http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Anie> <http://dbpedia.org/resource/Combined_oral_contraceptive_pill>
# http://dbpedia.org/resource/Svalbard http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/Northern_Europe>
# http://dbpedia.org/resource/Nicaragua http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Centrale_(Croydon)> <http://dbpedia.org/resource/Centrale_Region,_Togo>
# http://dbpedia.org/resource/Democratic_Republic_of_the_Congo http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Colombia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Arrondissements_of_the_Corse-du-Sud_department> <http://dbpedia.org/resource/South_Australia>
# http://dbpedia.org/resource/Seychelles http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Comoros http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Saint_Pierre_and_Miquelon http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/North_Island_(Mangrove_Islands)> <http://dbpedia.org/resource/North_Island>
# http://dbpedia.org/resource/Indonesia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Southeast_Asia>
# http://dbpedia.org/resource/Russia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/South_Korea http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/Eritrea http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Gabon http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Herm http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/Northern_Europe>
# http://dbpedia.org/resource/Cuba http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Centrale_(Croydon)> <http://dbpedia.org/resource/Centrale_Region,_Togo>
# http://dbpedia.org/resource/New_Caledonia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Anie> <http://dbpedia.org/resource/Oceanside,_California>
# http://dbpedia.org/resource/Western_Sahara http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Jersey http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/Northern_Europe>
# http://dbpedia.org/resource/Iceland http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/Northern_Europe>
# http://dbpedia.org/resource/Bhutan http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Southeast_Asia>
# http://dbpedia.org/resource/Marshall_Islands http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Anie> <http://dbpedia.org/resource/Combined_oral_contraceptive_pill>
# http://dbpedia.org/resource/Saint_Kitts_and_Nevis http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Centrale_(Croydon)> <http://dbpedia.org/resource/Central_Administrative_Okrug>
# http://dbpedia.org/resource/Bermuda http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/North_Island_(Mangrove_Islands)> <http://dbpedia.org/resource/North_Island>
# http://dbpedia.org/resource/Cameroon http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Channel_Islands http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/Northern_Europe>
# http://dbpedia.org/resource/Alderney http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/Northern_Europe>
# http://dbpedia.org/resource/Algeria http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Botswana http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Spain http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Italy http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Nigeria http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Liberia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/China http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/New_Zealand http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Anie> <http://dbpedia.org/resource/Combined_oral_contraceptive_pill>
# http://dbpedia.org/resource/Hong_Kong http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/Kazakhstan http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/India http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/Armenia http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Asia>
# http://dbpedia.org/resource/Mauritius http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Air_Afrique> <http://dbpedia.org/resource/Africa>
# http://dbpedia.org/resource/Kingdom_of_Tahiti http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Anie> <http://dbpedia.org/resource/Combined_oral_contraceptive_pill>
# http://dbpedia.org/resource/Turkmenistan http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Asia_(Roman_province)> <http://dbpedia.org/resource/Southeast_Asia>
# http://dbpedia.org/resource/Denmark http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/El_Salvador http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Centrale_(Croydon)> <http://dbpedia.org/resource/Centrale_Region,_Togo>
# http://dbpedia.org/resource/Canada http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/North_Island_(Mangrove_Islands)> <http://dbpedia.org/resource/North_Island>
# http://dbpedia.org/resource/Uruguay http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Arrondissements_of_the_Corse-du-Sud_department> <http://dbpedia.org/resource/South_Australia>
# http://dbpedia.org/resource/Monaco http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Jamaica http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Centrale_(Croydon)> <http://dbpedia.org/resource/Centrale_Region,_Togo>
# http://dbpedia.org/resource/Argentina http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Arrondissements_of_the_Corse-du-Sud_department> <http://dbpedia.org/resource/South_Australia>
# http://dbpedia.org/resource/San_Marino http://dbpedia.org/ontology/region
# <http://dbpedia.org/resource/Category:Europe_(band)_members> <http://dbpedia.org/resource/East-Central_Europe>
# http://dbpedia.org/resource/Romania http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Category:Bucharest> <http://dbpedia.org/resource/Bucharest>
# http://dbpedia.org/resource/Guernsey http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Category:Saint_Peter_Port> <http://dbpedia.org/resource/Saint_Peter_Port>
# http://dbpedia.org/resource/Latvia http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Riga_Township,_Michigan> <http://dbpedia.org/resource/Riga>
# http://dbpedia.org/resource/Ukraine http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Kief,_North_Dakota> <http://dbpedia.org/resource/Kiev_Oblast>
# http://dbpedia.org/resource/Slovenia http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/City_Municipality_of_Ljubljana> <http://dbpedia.org/resource/Ljubljana>
# http://dbpedia.org/resource/Swaziland http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Lobamba> <http://dbpedia.org/resource/Mbabane>
# http://dbpedia.org/resource/Sweden http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/MV_Azores> <http://dbpedia.org/resource/Stockholm_County>
# http://dbpedia.org/resource/Sri_Lanka http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Colombo_(aero-engine_manufacturer)> <http://dbpedia.org/resource/Colombo_District>
# http://dbpedia.org/resource/Norway http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Oslo_(disambiguation)> <http://dbpedia.org/resource/Oslofjord>
# http://dbpedia.org/resource/Lithuania http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Vilnius_railway_station> <http://dbpedia.org/resource/Vilnius>
# http://dbpedia.org/resource/Greenland http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Nuuk_(album)> <http://dbpedia.org/resource/Nuuk>
# http://dbpedia.org/resource/Macau http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Category:Macao> <http://dbpedia.org/resource/Macau>
# http://dbpedia.org/resource/French_Guiana http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Cayenne_pepper> <http://dbpedia.org/resource/Category:Cayenne>
# http://dbpedia.org/resource/Switzerland http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Bern,_Idaho> <http://dbpedia.org/resource/Bern>
# http://dbpedia.org/resource/Romania http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Category:Bucharest> <http://dbpedia.org/resource/Bucharest>
# http://dbpedia.org/resource/Guernsey http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Category:Saint_Peter_Port> <http://dbpedia.org/resource/Saint_Peter_Port>
# http://dbpedia.org/resource/Latvia http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Riga_Township,_Michigan> <http://dbpedia.org/resource/Riga>
# http://dbpedia.org/resource/Ukraine http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Kief,_North_Dakota> <http://dbpedia.org/resource/Kiev_Oblast>
# http://dbpedia.org/resource/Slovenia http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/City_Municipality_of_Ljubljana> <http://dbpedia.org/resource/Ljubljana>
# http://dbpedia.org/resource/Swaziland http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Lobamba> <http://dbpedia.org/resource/Mbabane>
# http://dbpedia.org/resource/Sweden http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/MV_Azores> <http://dbpedia.org/resource/Stockholm_County>
# http://dbpedia.org/resource/Sri_Lanka http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Colombo_(aero-engine_manufacturer)> <http://dbpedia.org/resource/Colombo_District>
# http://dbpedia.org/resource/Norway http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Oslo_(disambiguation)> <http://dbpedia.org/resource/Oslofjord>
# http://dbpedia.org/resource/Lithuania http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Vilnius_railway_station> <http://dbpedia.org/resource/Vilnius>
# http://dbpedia.org/resource/Greenland http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Nuuk_(album)> <http://dbpedia.org/resource/Nuuk>
# http://dbpedia.org/resource/Macau http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Category:Macao> <http://dbpedia.org/resource/Macau>
# http://dbpedia.org/resource/French_Guiana http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Cayenne_pepper> <http://dbpedia.org/resource/Category:Cayenne>
# http://dbpedia.org/resource/Switzerland http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Bern,_Idaho> <http://dbpedia.org/resource/Bern>
# http://dbpedia.org/resource/Guyana http://dbpedia.org/ontology/timeZone
# <http://dbpedia.org/resource/4.0> <http://dbpedia.org/resource/EMV>
# http://dbpedia.org/resource/Suriname http://dbpedia.org/ontology/timeZone
# <http://dbpedia.org/resource/3.0_(professional_wrestling)> <http://dbpedia.org/resource/BMW_E9>
# http://dbpedia.org/resource/Chile http://dbpedia.org/ontology/timeZone
# <http://dbpedia.org/resource/4.0> <http://dbpedia.org/resource/EMV>
# http://dbpedia.org/resource/United_States http://dbpedia.org/ontology/timeZone
# <http://dbpedia.org/resource/5.0> <http://dbpedia.org/resource/Equifax>
# http://dbpedia.org/resource/Saint_Lucia http://dbpedia.org/ontology/timeZone
# <http://dbpedia.org/resource/4.0> <http://dbpedia.org/resource/EMV>
# http://dbpedia.org/resource/Grenada http://dbpedia.org/ontology/timeZone
# <http://dbpedia.org/resource/4.0> <http://dbpedia.org/resource/EMV>
# http://dbpedia.org/resource/Dominican_Republic http://dbpedia.org/ontology/timeZone
# <http://dbpedia.org/resource/4.0> <http://dbpedia.org/resource/EMV>
# http://dbpedia.org/resource/Saint_Vincent_and_the_Grenadines http://dbpedia.org/ontology/timeZone
# <http://dbpedia.org/resource/4.0> <http://dbpedia.org/resource/EMV>
# http://dbpedia.org/resource/Guinea http://dbpedia.org/ontology/timeZone
# <http://dbpedia.org/resource/Bavaria_non-alcoholic_beer> <http://dbpedia.org/resource/Sony_Ericsson_K750>
# http://dbpedia.org/resource/Greenland http://dbpedia.org/ontology/timeZone
# <http://dbpedia.org/resource/3.0_(professional_wrestling)> <http://dbpedia.org/resource/BMW_E9>
# http://dbpedia.org/resource/Antigua_and_Barbuda http://dbpedia.org/ontology/timeZone
# <http://dbpedia.org/resource/4.0> <http://dbpedia.org/resource/EMV>
# http://dbpedia.org/resource/French_Guiana http://dbpedia.org/ontology/timeZone
# <http://dbpedia.org/resource/3.0_(professional_wrestling)> <http://dbpedia.org/resource/BMW_E9>
# http://dbpedia.org/resource/Saint_Pierre_and_Miquelon http://dbpedia.org/ontology/timeZone
# <http://dbpedia.org/resource/3.0_(professional_wrestling)> <http://dbpedia.org/resource/BMW_E9>
# http://dbpedia.org/resource/Western_Sahara http://dbpedia.org/ontology/timeZone
# <http://dbpedia.org/resource/Bavaria_non-alcoholic_beer> <http://dbpedia.org/resource/Sony_Ericsson_K750>
# http://dbpedia.org/resource/Saint_Kitts_and_Nevis http://dbpedia.org/ontology/timeZone
# <http://dbpedia.org/resource/4.0> <http://dbpedia.org/resource/EMV>
# http://dbpedia.org/resource/Channel_Islands http://dbpedia.org/ontology/timeZone
# <http://dbpedia.org/resource/Bavaria_non-alcoholic_beer> <http://dbpedia.org/resource/Sony_Ericsson_K750>
# http://dbpedia.org/resource/Canada http://dbpedia.org/ontology/timeZone
# <http://dbpedia.org/resource/5.0> <http://dbpedia.org/resource/Ford_Modular_engine>
# http://dbpedia.org/resource/Jamaica http://dbpedia.org/ontology/timeZone
# <http://dbpedia.org/resource/5.0> <http://dbpedia.org/resource/Ford_Modular_engine>
# TableResults(redundant=388, novel=277, errors=2, numeric=2)
# Processing table 5 11688006_0_8123036130090004213.csv
# http://dbpedia.org/resource/Monaco http://dbpedia.org/ontology/PopulatedPlace/area
# <http://dbpedia.org/resource/Version_2.0> <http://dbpedia.org/resource/3.0_(professional_wrestling)>
# TableResults(redundant=0, novel=6, errors=1317, numeric=0)
# Processing table 6 11833461_1_3811022039809817402.csv
# http://dbpedia.org/resource/Super_Star_Wars http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/UTC+09:00> <http://dbpedia.org/resource/Quoted-printable>
# http://dbpedia.org/resource/Space_Invaders http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/Eleven_@_11:00> <http://dbpedia.org/resource/UTC+11:00>
# http://dbpedia.org/resource/Final_Fight http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/UTC+04:00> <http://dbpedia.org/resource/Category:Wikipedia_Signpost_archives_2007-04>
# http://dbpedia.org/resource/Street_Fighter_II_Turbo:_Hyper_Fighting http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/July_2007> <http://dbpedia.org/resource/UTC+07:00>
# http://dbpedia.org/resource/Gradius_III http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/UTC+09:00> <http://dbpedia.org/resource/Quoted-printable>
# http://dbpedia.org/resource/Super_Mario_RPG:_Legend_of_the_Seven_Stars http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/UTC+08:00> <http://dbpedia.org/resource/OO_gauge>
# http://dbpedia.org/resource/Donkey_Kong_Country http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/Midnight> <http://dbpedia.org/resource/UTC+12:00>
# http://dbpedia.org/resource/Donkey_Kong_Country_3:_Dixie_Kong's_Double_Trouble! http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/Midnight> <http://dbpedia.org/resource/UTC+12:00>
# http://dbpedia.org/resource/Kirby's_Avalanche http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/July_2007> <http://dbpedia.org/resource/UTC+07:00>
# http://dbpedia.org/resource/Super_Star_Wars http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/UTC+09:00> <http://dbpedia.org/resource/Quoted-printable>
# http://dbpedia.org/resource/Space_Invaders http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/Eleven_@_11:00> <http://dbpedia.org/resource/UTC+11:00>
# http://dbpedia.org/resource/Final_Fight http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/UTC+04:00> <http://dbpedia.org/resource/Category:Wikipedia_Signpost_archives_2007-04>
# http://dbpedia.org/resource/Street_Fighter_II_Turbo:_Hyper_Fighting http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/July_2007> <http://dbpedia.org/resource/UTC+07:00>
# http://dbpedia.org/resource/Gradius_III http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/UTC+09:00> <http://dbpedia.org/resource/Quoted-printable>
# http://dbpedia.org/resource/Super_Mario_RPG:_Legend_of_the_Seven_Stars http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/UTC+08:00> <http://dbpedia.org/resource/OO_gauge>
# http://dbpedia.org/resource/Donkey_Kong_Country http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/Midnight> <http://dbpedia.org/resource/UTC+12:00>
# http://dbpedia.org/resource/Donkey_Kong_Country_3:_Dixie_Kong's_Double_Trouble! http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/Midnight> <http://dbpedia.org/resource/UTC+12:00>
# http://dbpedia.org/resource/Kirby's_Avalanche http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/July_2007> <http://dbpedia.org/resource/UTC+07:00>
# http://dbpedia.org/resource/Harvest_Moon_(video_game) http://dbpedia.org/ontology/publisher
# <http://dbpedia.org/resource/Natsume's_Book_of_Friends> <http://dbpedia.org/resource/Natsume_(company)>
# http://dbpedia.org/resource/Space_Invaders http://dbpedia.org/ontology/publisher
# <http://dbpedia.org/resource/Taito_(kanji)> <http://dbpedia.org/resource/Taito_Corporation>
# http://dbpedia.org/resource/Secret_of_Mana http://dbpedia.org/ontology/publisher
# <http://dbpedia.org/resource/Square_Enix> <http://dbpedia.org/resource/Eidos_Interactive>
# http://dbpedia.org/resource/R-Type_III:_The_Third_Lightning http://dbpedia.org/ontology/publisher
# <http://dbpedia.org/resource/Irem_(construction_company)> <http://dbpedia.org/resource/Irem>
# http://dbpedia.org/resource/Super_R-Type http://dbpedia.org/ontology/publisher
# <http://dbpedia.org/resource/Irem_(construction_company)> <http://dbpedia.org/resource/Irem>
# http://dbpedia.org/resource/Chrono_Trigger http://dbpedia.org/ontology/publisher
# <http://dbpedia.org/resource/Square_Enix> <http://dbpedia.org/resource/Eidos_Interactive>
# http://dbpedia.org/resource/Harvest_Moon_(video_game) http://dbpedia.org/ontology/publisher
# <http://dbpedia.org/resource/Natsume's_Book_of_Friends> <http://dbpedia.org/resource/Natsume_(company)>
# http://dbpedia.org/resource/Space_Invaders http://dbpedia.org/ontology/publisher
# <http://dbpedia.org/resource/Taito_(kanji)> <http://dbpedia.org/resource/Taito_Corporation>
# http://dbpedia.org/resource/Secret_of_Mana http://dbpedia.org/ontology/publisher
# <http://dbpedia.org/resource/Square_Enix> <http://dbpedia.org/resource/Eidos_Interactive>
# http://dbpedia.org/resource/R-Type_III:_The_Third_Lightning http://dbpedia.org/ontology/publisher
# <http://dbpedia.org/resource/Irem_(construction_company)> <http://dbpedia.org/resource/Irem>
# http://dbpedia.org/resource/Super_R-Type http://dbpedia.org/ontology/publisher
# <http://dbpedia.org/resource/Irem_(construction_company)> <http://dbpedia.org/resource/Irem>
# http://dbpedia.org/resource/Chrono_Trigger http://dbpedia.org/ontology/publisher
# <http://dbpedia.org/resource/Square_Enix> <http://dbpedia.org/resource/Eidos_Interactive>
# http://dbpedia.org/resource/Super_Star_Wars http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/UTC+09:00> <http://dbpedia.org/resource/Quoted-printable>
# http://dbpedia.org/resource/Space_Invaders http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/Eleven_@_11:00> <http://dbpedia.org/resource/UTC+11:00>
# http://dbpedia.org/resource/Final_Fight http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/UTC+04:00> <http://dbpedia.org/resource/Category:Wikipedia_Signpost_archives_2007-04>
# http://dbpedia.org/resource/Street_Fighter_II_Turbo:_Hyper_Fighting http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/July_2007> <http://dbpedia.org/resource/UTC+07:00>
# http://dbpedia.org/resource/Gradius_III http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/UTC+09:00> <http://dbpedia.org/resource/Quoted-printable>
# http://dbpedia.org/resource/Super_Mario_RPG:_Legend_of_the_Seven_Stars http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/UTC+08:00> <http://dbpedia.org/resource/OO_gauge>
# http://dbpedia.org/resource/Donkey_Kong_Country http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/Midnight> <http://dbpedia.org/resource/UTC+12:00>
# http://dbpedia.org/resource/Donkey_Kong_Country_3:_Dixie_Kong's_Double_Trouble! http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/Midnight> <http://dbpedia.org/resource/UTC+12:00>
# http://dbpedia.org/resource/Kirby's_Avalanche http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/July_2007> <http://dbpedia.org/resource/UTC+07:00>
# http://dbpedia.org/resource/Super_Star_Wars http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/UTC+09:00> <http://dbpedia.org/resource/Quoted-printable>
# http://dbpedia.org/resource/Space_Invaders http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/Eleven_@_11:00> <http://dbpedia.org/resource/UTC+11:00>
# http://dbpedia.org/resource/Final_Fight http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/UTC+04:00> <http://dbpedia.org/resource/Category:Wikipedia_Signpost_archives_2007-04>
# http://dbpedia.org/resource/Street_Fighter_II_Turbo:_Hyper_Fighting http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/July_2007> <http://dbpedia.org/resource/UTC+07:00>
# http://dbpedia.org/resource/Gradius_III http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/UTC+09:00> <http://dbpedia.org/resource/Quoted-printable>
# http://dbpedia.org/resource/Super_Mario_RPG:_Legend_of_the_Seven_Stars http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/UTC+08:00> <http://dbpedia.org/resource/OO_gauge>
# http://dbpedia.org/resource/Donkey_Kong_Country http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/Midnight> <http://dbpedia.org/resource/UTC+12:00>
# http://dbpedia.org/resource/Donkey_Kong_Country_3:_Dixie_Kong's_Double_Trouble! http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/Midnight> <http://dbpedia.org/resource/UTC+12:00>
# http://dbpedia.org/resource/Kirby's_Avalanche http://dbpedia.org/ontology/releaseDate
# <http://dbpedia.org/resource/July_2007> <http://dbpedia.org/resource/UTC+07:00>
# TableResults(redundant=100, novel=136, errors=134, numeric=0)
# Processing table 7 12125836_0_1134348206297032434.csv
# http://dbpedia.org/resource/KMRB http://dbpedia.org/ontology/programmeFormat
# <http://dbpedia.org/resource/Cantonese_opera> <http://dbpedia.org/resource/Cantonese>
# http://dbpedia.org/resource/KMRB http://dbpedia.org/ontology/programmeFormat
# <http://dbpedia.org/resource/Cantonese_opera> <http://dbpedia.org/resource/Cantonese>
# TableResults(redundant=56, novel=2, errors=0, numeric=0)
# Processing table 8 12183399_0_6725061928072492226.csv
# http://dbpedia.org/resource/France http://dbpedia.org/ontology/currency
# <http://dbpedia.org/resource/French_franc> <http://dbpedia.org/resource/France>
# http://dbpedia.org/resource/South_Korea http://dbpedia.org/ontology/currency
# <http://dbpedia.org/resource/Korean_won> <http://dbpedia.org/resource/South_Korean_won>
# TableResults(redundant=140, novel=7, errors=1, numeric=0)
# Processing table 9 12193237_0_8699643798888088574.csv
# http://dbpedia.org/resource/Belarus http://dbpedia.org/ontology/language
# <http://dbpedia.org/resource/Belarusian> <http://dbpedia.org/resource/Belarusians>
# http://dbpedia.org/resource/Sweden http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/MV_Azores> <http://dbpedia.org/resource/Stockholm_County>
# http://dbpedia.org/resource/Switzerland http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Bern,_Idaho> <http://dbpedia.org/resource/Bern>
# http://dbpedia.org/resource/Norway http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Oslo_(disambiguation)> <http://dbpedia.org/resource/Oslofjord>
# http://dbpedia.org/resource/Sweden http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/MV_Azores> <http://dbpedia.org/resource/Stockholm_County>
# http://dbpedia.org/resource/Switzerland http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Bern,_Idaho> <http://dbpedia.org/resource/Bern>
# http://dbpedia.org/resource/Norway http://dbpedia.org/ontology/capital
# <http://dbpedia.org/resource/Oslo_(disambiguation)> <http://dbpedia.org/resource/Oslofjord>
# TableResults(redundant=133, novel=27, errors=0, numeric=0)
